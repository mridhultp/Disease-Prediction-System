# %% [markdown]
# # Import dependencies

# %%
import numpy as np
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn import svm
from sklearn.metrics import accuracy_score

# %% [markdown]
# Load data to the pandas dataframe

# %% [markdown]
# First 5 rows

# %%
parkinson_dataset = pd.read_csv('Parkinsson disease.csv')

# %%
parkinson_dataset.head()
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  ...   spread1   spread2        D2       PPE
# 0  phon_R01_S01_1      119.992       157.302        74.997  ... -4.813031  0.266482  2.301442  0.284654
# 1  phon_R01_S01_2      122.400       148.650       113.819  ... -4.075192  0.335590  2.486855  0.368674
# 2  phon_R01_S01_3      116.682       131.111       111.555  ... -4.443179  0.311173  2.342259  0.332634
# 3  phon_R01_S01_4      116.676       137.871       111.366  ... -4.117501  0.334147  2.405554  0.368975
# 4  phon_R01_S01_5      116.014       141.781       110.655  ... -3.747787  0.234513  2.332180  0.410335
#
# [5 rows x 24 columns]

# %%
parkinson_datset.shape
# Out:
# (195, 24)

# %%
parkinson_dataset.isnull().sum()
# Out:
# name                0
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# dtype: int64

# %%
parkinson_dataset.describe()
# Out:
#        MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  ...     spread1     spread2          D2         PPE
# count   195.000000    195.000000    195.000000      195.000000  ...  195.000000  195.000000  195.000000  195.000000
# mean    154.228641    197.104918    116.324631        0.006220  ...   -5.684397    0.226510    2.381826    0.206552
# std      41.390065     91.491548     43.521413        0.004848  ...    1.090208    0.083406    0.382799    0.090119
# min      88.333000    102.145000     65.476000        0.001680  ...   -7.964984    0.006274    1.423287    0.044539
# 25%     117.572000    134.862500     84.291000        0.003460  ...   -6.450096    0.174351    2.099125    0.137451
# 50%     148.790000    175.829000    104.315000        0.004940  ...   -5.720868    0.218885    2.361532    0.194052
# 75%     182.769000    224.205500    140.018500        0.007365  ...   -5.046192    0.279234    2.636456    0.252980
# ...

# %%
parkinson_dataset['status'].value_counts()
# Out:
# status
# 1    147
# 0     48
# Name: count, dtype: int64

# %%
# Label distribution in status column

# %%
parkinson_dataset['status'].value_counts().plot(kind='bar')
plt.show()

# %% [markdown]
# 0 ---> Parkinson positive
#
# 1 ---> Healthy

# %%
parkinson_dataset=parkinson_dataset.drop(['name'], axis=1)

# %%
parkinson_dataset.groupby('status').mean()
# Out:
#         MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  ...   spread1   spread2        D2       PPE
# status                                                           ...
# 0        181.937771    223.636750    145.207292        0.003866  ... -6.759264  0.160292  2.154491  0.123017
# 1        145.180762    188.441463    106.893558        0.006989  ... -5.333420  0.248133  2.456058  0.233828
#
# [2 rows x 22 columns]

# %% [markdown]
# Data Preprocessing

# %% [markdown]
# # Split features and Lable

# %%
X = parkinson_dataset.drop(['status'], axis=1)

# %%
Y = parkinson_dataset['status']

# %%
X
# Out:
#      MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  ...   spread1   spread2        D2       PPE
# 0        119.992       157.302        74.997         0.00784  ... -4.813031  0.266482  2.301442  0.284654
# 1        122.400       148.650       113.819         0.00968  ... -4.075192  0.335590  2.486855  0.368674
# 2        116.682       131.111       111.555         0.01050  ... -4.443179  0.311173  2.342259  0.332634
# 3        116.676       137.871       111.366         0.00997  ... -4.117501  0.334147  2.405554  0.368975
# 4        116.014       141.781       110.655         0.01284  ... -3.747787  0.234513  2.332180  0.410335
# ..           ...           ...           ...             ...  ...       ...       ...       ...       ...
# 190      174.188       230.978        94.261         0.00459  ... -6.538586  0.121952  2.657476  0.133050
# 191      209.516       253.017        89.488         0.00564  ... -6.195325  0.129303  2.784312  0.168895
# ...

# %%
Y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 190    0
# 191    0
# 192    0
# 193    0
# 194    0
# Name: status, Length: 195, dtype: int64

# %% [markdown]
# # Split Train Test data

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=42,stratify=Y)

# %%
print(X.shape,X_train.shape,X_test.shape)
# Out:
# (195, 22) (156, 22) (39, 22)

# %% [markdown]
# # Data Standardization

# %%
scaler = StandardScaler()

# %%
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
X_train = scaler.transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %%
X_train
# Out:
# array([[-1.06344643, -0.9157626 , -0.33580464, ..., -0.42503608,
#         -1.26010198, -0.39131778],
#        [ 0.58342091,  0.12149404, -0.93052313, ...,  1.44380997,
#          1.76000577,  0.35952829],
#        [-1.07057001, -0.75769779, -0.20592359, ...,  1.18302374,
#          0.59341426,  0.20707672],
#        ...,
#        [-0.8255786 , -0.75169732, -0.33412566, ..., -0.28545982,
#          0.36367078, -0.43803646],
#        [ 1.21627388,  0.18966471,  1.98934195, ..., -0.5966076 ,
#         -2.11947968, -1.69501069],
#        [-0.82640055, -0.78369603, -0.22465621, ..., -0.11949367,
#          0.33377162, -0.43019293]])

# %% [markdown]
# # Model Training

# %% [markdown]
# Support vector mechine

# %%
model = svm.SVC(kernel='linear')

# %%
# Training the SVM model with training data

# %%
model.fit(X_train,Y_train)
# Out:
# SVC(kernel='linear')

# %% [markdown]
# # Model Evaluation

# %%
# Accuracy score on training data

# %%
X_train_pred = model.predict(X_train)

# %%
training_data_accuracy= accuracy_score(X_train_pred,Y_train)

# %%
print('Accuracy Score on training data :', training_data_accuracy)
# Out:
# Accuracy Score on training data : 0.9038461538461539

# %%
# Accuracy score on test data

# %%
X_test_pred = model.predict(X_test)

# %%
test_data_accuracy= accuracy_score(X_test_pred,Y_test)

# %%
print('Accuracy Score on test data :', test_data_accuracy)
# Out:
# Accuracy Score on test data : 0.9487179487179487

# %% [markdown]
# # Building a predictive model

# %%
input_data = (198.383,215.203,193.104,0.00212,0.00001,0.00113,0.00135,0.00339,0.01263,0.111,0.0064,0.00825,0.00951,0.01919,0.00119,30.775,0.465946,0.738703,-7.067931,0.175181,1.512275,0.09632
)

# %%
#convert the sets to numpy array

# %%
num_arry= np.asarray(input_data)

# %%
# reshap num_array

# %%
input_data_reshaped = num_arry.reshape(1,-1)

# %%
#standardize the data

# %%
std_data = scaler.transform(input_data_reshaped)
# Out:
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
prediction = model.predict(std_data)

# %%
print(prediction)
# Out:
# [0]
